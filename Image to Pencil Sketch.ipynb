# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
filename = 'msd1.jpg'

# %%
img = cv2.imread(filename)

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
inverted_gray_img = 255 - gray_img

# %%
blurred = cv2.GaussianBlur(inverted_gray_img, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred

# %%
pencil_sketch = cv2.divide(gray_img, inverted_blurred, scale = 256.0)

# %%
import matplotlib.pyplot as plt

# %%
cv2_imshow(img)
cv2_imshow(gray_img)
cv2_imshow(inverted_gray_img)
# Out:
# <PIL.Image.Image image mode=RGB size=563x568 at 0x7F92080A9FA0>
# <PIL.Image.Image image mode=L size=563x568 at 0x7F91FD014790>
# <PIL.Image.Image image mode=L size=563x568 at 0x7F91FD014700>

# %%
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=563x568 at 0x7F91FD014700>
